# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np
import time
# %matplotlib notebook

# %%
data = np.loadtxt('sim_results/sim_results_5_2_left_100m_50_0.20_0.50_0.20_0.40_0.10_0.30_cardata.txt')

# %%
fig, ax = plt.subplots(figsize=(8,3))
grph, = ax.plot([],[], 'o')
ax.set_xlim(3500,4500)
ax.set_ylim(-0.5,5.5)
#timetext = ax.text(180,5, '%d'%0)

t0 = 6000
grph.set_data(data[data[:,0]==t0,1],data[data[:,0]==t0,2])


def animate(t):
    grph.set_data(data[data[:,0]==t+t0,1],data[data[:,0]==t+t0,2])
    #timetext.set_text('%d'%t)
    return [grph]
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# blit=True re-draws only the parts that have changed.
anim = animation.FuncAnimation(fig, animate, frames=20*60, interval=100, blit=True)

# %%
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 from IPython.display import HTML
# ----> 2 HTML(anim.to_html5_video())
#
# File U:\miguel\pyenvs\trafficC\lib\site-packages\matplotlib\animation.py:1266, in Animation.to_html5_video(self, embed_limit)
#    1263 path = Path(tmpdir, "temp.m4v")
#    1264 # We create a writer manually so that we can get the
#    1265 # appropriate size for the tag
# -> 1266 Writer = writers[mpl.rcParams['animation.writer']]
#    1267 writer = Writer(codec='h264',
#    1268                 bitrate=mpl.rcParams['animation.bitrate'],
#    1269                 fps=1000. / self._interval)
#    1270 self.save(str(path), writer=writer)
#
# File U:\miguel\pyenvs\trafficC\lib\site-packages\matplotlib\animation.py:151, in MovieWriterRegistry.__getitem__(self, name)
#     149 if self.is_available(name):
# ...

# %%
data[(data[:,4]<0)]

# %%
data[:,0]

# %%
[print(i) for i in data[(data[:,4]<0) & (data[:,1]>17)]]

# %%
[print(i) for i in data[(data[:,-1]==55)]]

# %%
[print(i) for i in data[(data[:,0]==401)]]

# %%
[print(i) for i in data[(data[:,0]==402)]]

# %%
[print(i) for i in data[(data[:,0]==403)]]
